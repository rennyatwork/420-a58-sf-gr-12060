# %% [markdown]
# **420-A58-SF - Algorithmes d'apprentissage non supervisé - Hiver 2023 - Spécialisation technique en Intelligence Artificielle**<br/>
# MIT License - Copyright (c) 2023 Mikaël Swawola

# %% [markdown]
# # Evaluation formative #1

# %% [markdown]
# * Durée: 45 minutes
# * Travail individuel
# * Documents autorisés
# * Remettre ce notebook complété de vos réponses sur Lea

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## 1 - Lecture des données

# %% [markdown]
# **Charger le fichier `ef1.csv` et répondre aux questions suivantes:**

# %% [markdown]
# **Q1.1 - Combien de variables indépendantes sont présentes dans ce jeu de données?** (2.5 points)

# %%
# Compléter code + réponse à la question au format Markdown
import pandas as pd

X = pd.read_csv("../../data/ef1.csv").values
X
# Out:
# array([[-1.4580368 ,  5.2569366 ,  3.45875315,  9.36121079,  5.03752468,
#         -9.77912863],
#        [ 2.96234096, -1.90733799,  9.54354993, -7.42250712,  5.09500208,
#         -1.44223819],
#        [ 3.86661699,  7.10606518,  4.89930634,  1.92076486, -7.11750809,
#         -8.52628375],
#        ...,
#        [ 4.12592364, -0.97608693,  7.83730075, -6.5563749 ,  4.35316822,
#          1.71903462],
#        [-4.17516172, -2.96391031, -4.01265454, 10.1172612 ,  4.24031249,
#         -1.70101666],
#        [ 1.89721688, -3.99021275,  5.1719166 ,  5.18283219,  8.75076636,
#          2.24767741]])

# %% [markdown]
# **Q1.2 - Les données sont-elles à l'échelle ?**  (2.5 points)

# %%
# Compléter code + réponse à la question au format Markdown

0    0.769862
1    0.038630
2    3.857284
3    3.590971
4    2.446363
5   -3.055353
# Out:
# 0    0.769862
# 1    0.038630
# 2    3.857284
# 3    3.590971
# 4    2.446363
# 5   -3.055353
# dtype: float64

# %% [markdown]
# **Q1.3 - Une visualisation (à vous de déterminer laquelle) permet-elle de trouver aisément le nombre de clusters présents ? Justifier votre réponse.** (2.5 points)

# %%
# Compléter code + réponse à la question au format Markdown
import seaborn as sns

#_ = sns.scatterplot(x=X[:,3], y=X[:,4], data=X)

_ = sns.scatterplot(x=X[:,0], y=X[:,1], data=X)

# %%
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(X)
X_pca = pca.transform(X)

# %%
_ = sns.scatterplot(x=X_pca[:,0], y=X_pca[:,1], data=X_pca)
pca.explained_variance_ratio_
#plotly
# Out:
# array([0.46282233, 0.38147404, 0.10831435, 0.03475639, 0.00657047,
#        0.00606242])

# %% [markdown]
# ## 2 - Recherche des clusters par la méthodes des K-moyennes

# %% [markdown]
# **Q2.1 - En vous basant sur la valeur de K estimée à la question précédente, recherchez les clusters présents dans le jeu de données à l'aide de la méthode des K-moyennes. Utiliser scikit-learn.** (5 points)

# %%
# Compléter code
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, n_init=100).fit(X)

# %% [markdown]
# **Q2.2 - Afficher les clusters obtenus à l'aide d'un diagramme en nuages de points.** (2.5 points)

# %%
# Compléter code
_ = sns.scatterplot(x=X_pca[:,0], y=X_pca[:,1], data=X_pca, hue=kmeans.labels_)

# %% [markdown]
# **Q2.3 - Trouver le nombre de clusters K à l'aide de la technique du "coude". Justifier votre réponse.** (5 points)

# %%
# Compléter code + réponse à la question au format Markdown

disto = []
for k in range(1,10):
    kmeans = KMeans(n_clusters=k, n_init=100).fit(X)
    disto.append(kmeans.inertia_)

# %%
import matplotlib.pyplot as plt
plt.plot(disto)

# %% [markdown]
# **Fin de l'évaluation formative #1**
